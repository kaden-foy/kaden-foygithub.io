# %%
import numpy as np
import matplotlib.pyplot as plt
import raytracing as ray

# %%
path = ray.ImagingPath()
path.append(ray.Space(d=50))
path.append(ray.Lens(f=50, diameter=25))
path.append(ray.Space(d=120))
path.append(ray.Lens(f=70))
path.append(ray.Space(d=100))
path.display()
# Out:
# c:\users\kaden\appdata\local\programs\python\python39\lib\site-packages\raytracing\figure.py: 115
# BeginnerHint: Infinite field of view: cannot use limitObjectToFieldOfView=True. The object height is instead set to the default value of 10.0.
#
# c:\users\kaden\appdata\local\programs\python\python39\lib\site-packages\raytracing\imagingpath.py: 797
# BeginnerHint: Field of view is infinite. You can pass useObject=True to use the finite objectHeight.
#
# c:\users\kaden\appdata\local\programs\python\python39\lib\site-packages\raytracing\figure.py: 133
# BeginnerHint: No aperture stop in the system: cannot use onlyPrincipalAndAxialRays=True since they are not defined. Showing the default ObjectRays instead.
#
# c:\users\kaden\appdata\local\programs\python\python39\lib\site-packages\raytracing\utils.py: 101
# ...
